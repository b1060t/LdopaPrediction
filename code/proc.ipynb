# %%
from src.model.pipeline import run
import os

# %%
# Root directory as working directory
os.chdir('..')
os.getcwd()
# Out:
# '/home/biobot/disk/ldopa'

# %% [markdown]
# Baseline:
#
# SVM: 0.765 0.710
#
# XgBoost: 0.966 0.746
#
# AUC Table:
# | Model | Baseline | Texture |
# | --- | --- | --- |
# | SVM | 0.710 |  |
# | XgBoost | 0.746 |  |

# %%
baseline_auc, img_auc = run('pat_data', ['classification/2'], [['t1_radiomic']], print, plot_flag=False, feature_selection=True, cal_baselines=True)
# Out:
# Task: classification/2
#
# Feature: ['t1_radiomic']
#
# SEX chi2 p: 0.5414803876006902
# CAT chi2 p: 0.9510706628888684
# AGE Normaltest p_train: [0.07505303], p_test: [0.48389882]
# AGE t-test p: Ttest_indResult(statistic=array([1.54953415]), pvalue=array([0.12271054]))
# NUPDR3OF Normaltest p_train: [0.01407325], p_test: [0.53859285]
# NUPDR3OF ranksums p: RanksumsResult(statistic=array([0.53408144]), pvalue=array([0.59328519]))
# LEDD Normaltest p_train: [2.56158925e-12], p_test: [0.1798008]
# LEDD ranksums p: RanksumsResult(statistic=array([0.51837316]), pvalue=array([0.60419794]))
# DURATION Normaltest p_train: [0.00553476], p_test: [0.13860719]
# DURATION ranksums p: RanksumsResult(statistic=array([-0.45554005]), pvalue=array([0.64872076]))
# 100%|██████████| 50/50 [00:01<00:00, 29.90it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7654370489174017
#
# AUC test 0.7102272727272727
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9662523389468057
#
# AUC test 0.7462121212121212
#
# Accuracy train 0.9017341040462428
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7169206094627105
#
# AUC test 0.7178030303030303
#
# Accuracy train 0.6647398843930635
#
# Accuracy test 0.6086956521739131
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.720863405506549
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.7632575757575757
#
# Accuracy train 0.9942196531791907
#
# Accuracy test 0.6956521739130435
#
# Model: mlp
#
# AUC train 0.7122427158513766
#
# AUC test 0.7859848484848484
#
# Accuracy train 0.6184971098265896
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:01<00:00, 30.42it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7380379577653033
#
# AUC test 0.7291666666666666
#
# Accuracy train 0.7052023121387283
#
# Accuracy test 0.6521739130434783
#
# Model: xgboost
#
# AUC train 0.9472734562951083
#
# AUC test 0.7556818181818181
#
# Accuracy train 0.8728323699421965
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.6055867415129644
#
# AUC test 0.49810606060606055
#
# Accuracy train 0.49710982658959535
#
# Accuracy test 0.4782608695652174
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7570168404170008
#
# AUC test 0.7803030303030303
#
# Accuracy train 0.6820809248554913
#
# Accuracy test 0.7608695652173914
#
# Model: xgboost
#
# AUC train 0.9818230419673885
#
# AUC test 0.6780303030303031
#
# Accuracy train 0.9132947976878613
#
# Accuracy test 0.5869565217391305
#
# Model: mlp
#
# AUC train 0.7134456027800055
#
# AUC test 0.7954545454545455
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.717391304347826
# 100%|██████████| 50/50 [00:01<00:00, 29.39it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7159850307404437
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9902432504677894
#
# AUC test 0.7518939393939394
#
# Accuracy train 0.9364161849710982
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7246725474472067
#
# AUC test 0.7045454545454546
#
# Accuracy train 0.7052023121387283
#
# Accuracy test 0.6521739130434783
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7205960973001871
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 0.9990644212777332
#
# AUC test 0.7215909090909091
#
# Accuracy train 0.9826589595375722
#
# Accuracy test 0.6521739130434783
#
# Model: mlp
#
# AUC train 0.7014167334937184
#
# AUC test 0.7348484848484848
#
# Accuracy train 0.630057803468208
#
# Accuracy test 0.6521739130434783
# 100%|██████████| 50/50 [00:01<00:00, 25.99it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7659716653301256
#
# AUC test 0.7121212121212122
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9951884522854852
#
# AUC test 0.7367424242424243
#
# Accuracy train 0.953757225433526
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7185244587008821
#
# AUC test 0.7499999999999999
#
# Accuracy train 0.6820809248554913
#
# Accuracy test 0.717391304347826
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7205960973001871
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 0.7995188452285485
#
# AUC test 0.759469696969697
#
# Accuracy train 0.6936416184971098
#
# Accuracy test 0.6521739130434783
#
# Model: mlp
#
# AUC train 0.702085004009623
#
# AUC test 0.7992424242424242
#
# Accuracy train 0.6473988439306358
#
# Accuracy test 0.717391304347826
# 100%|██████████| 50/50 [00:01<00:00, 26.66it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7157177225340817
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.7771986099973269
#
# AUC test 0.725378787878788
#
# Accuracy train 0.6763005780346821
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.6986099973269179
#
# AUC test 0.740530303030303
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.6304347826086957
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7205960973001871
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 0.9899759422614274
#
# AUC test 0.7045454545454546
#
# Accuracy train 0.9421965317919075
#
# Accuracy test 0.6521739130434783
#
# Model: mlp
#
# AUC train 0.7205292702485967
#
# AUC test 0.8068181818181819
#
# Accuracy train 0.6763005780346821
#
# Accuracy test 0.7608695652173914
# 100%|██████████| 50/50 [00:01<00:00, 29.44it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7658380112269447
#
# AUC test 0.7121212121212122
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.950414327719861
#
# AUC test 0.7651515151515152
#
# Accuracy train 0.884393063583815
#
# Accuracy test 0.7391304347826086
#
# Model: mlp
#
# AUC train 0.7107725207163861
#
# AUC test 0.7291666666666666
#
# Accuracy train 0.6878612716763006
#
# Accuracy test 0.6956521739130435
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7205960973001871
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 0.797380379577653
#
# AUC test 0.7613636363636364
#
# Accuracy train 0.6936416184971098
#
# Accuracy test 0.6956521739130435
#
# Model: mlp
#
# AUC train 0.7003475006682706
#
# AUC test 0.7765151515151516
#
# Accuracy train 0.6473988439306358
#
# Accuracy test 0.7391304347826086
# 100%|██████████| 50/50 [00:01<00:00, 30.98it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7383052659716653
#
# AUC test 0.7272727272727273
#
# Accuracy train 0.7052023121387283
#
# Accuracy test 0.6521739130434783
#
# Model: xgboost
#
# AUC train 0.9251537022186581
#
# AUC test 0.7272727272727273
#
# Accuracy train 0.8554913294797688
#
# Accuracy test 0.6956521739130435
#
# Model: mlp
#
# AUC train 0.7103715584068432
#
# AUC test 0.7840909090909092
#
# Accuracy train 0.6358381502890174
#
# Accuracy test 0.6956521739130435
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7568831863138199
#
# AUC test 0.7803030303030303
#
# Accuracy train 0.6820809248554913
#
# Accuracy test 0.7608695652173914
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.6893939393939394
#
# Accuracy train 1.0
#
# Accuracy test 0.5869565217391305
#
# Model: mlp
#
# AUC train 0.6646618551189521
#
# AUC test 0.803030303030303
#
# Accuracy train 0.5895953757225434
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:01<00:00, 30.00it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7159850307404437
#
# AUC test 0.7357954545454546
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9037690457097033
#
# AUC test 0.7234848484848485
#
# Accuracy train 0.815028901734104
#
# Accuracy test 0.6304347826086957
#
# Model: mlp
#
# AUC train 0.7086340550654905
#
# AUC test 0.7784090909090909
#
# Accuracy train 0.653179190751445
#
# Accuracy test 0.6739130434782609
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7207965784549585
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.7405303030303031
#
# Accuracy train 1.0
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.6992782678428228
#
# AUC test 0.7897727272727272
#
# Accuracy train 0.6069364161849711
#
# Accuracy test 0.6739130434782609
# 100%|██████████| 50/50 [00:01<00:00, 29.04it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7151831061213579
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9161320502539428
#
# AUC test 0.7386363636363635
#
# Accuracy train 0.8323699421965318
#
# Accuracy test 0.7391304347826086
#
# Model: mlp
#
# AUC train 0.7034215450414328
#
# AUC test 0.8049242424242424
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.6521739130434783
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7205960973001871
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 0.9512162523389468
#
# AUC test 0.7518939393939396
#
# Accuracy train 0.8728323699421965
#
# Accuracy test 0.6521739130434783
#
# Model: mlp
#
# AUC train 0.7175888799786153
#
# AUC test 0.7840909090909091
#
# Accuracy train 0.653179190751445
#
# Accuracy test 0.6521739130434783
# 100%|██████████| 50/50 [00:01<00:00, 27.45it/s]
# mRMR Selected features: ['rTHA_original_glcm_Idn', 'rSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Skewness', 'rPUT_original_glcm_ClusterShade', 'rSN_original_firstorder_Minimum', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glszm_ZoneEntropy', 'rRN_original_glcm_Imc1', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_glszm_ZoneEntropy', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'lGPi_original_firstorder_Range', 'rCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'lCAU_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPe_original_glszm_GrayLevelVariance', 'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rGPe_original_firstorder_10Percentile', 'rPUT_original_glcm_Imc1', 'rGPe_original_glcm_ClusterShade', 'rSTN_original_gldm_DependenceEntropy', 'lRN_original_glcm_Correlation', 'lCAU_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_ClusterProminence', 'lGPi_original_glcm_Idmn', 'lTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rCAU_original_gldm_DependenceVariance', 'lCAU_original_glcm_Correlation', 'rSTN_original_firstorder_Minimum', 'rSTN_original_glrlm_GrayLevelNonUniformity', 'rPUT_original_glszm_GrayLevelNonUniformity', 'rRN_original_glcm_Idn', 'rCAU_original_firstorder_Skewness', 'lPUT_original_glcm_Imc1', 'lGPe_original_firstorder_Minimum', 'lSTN_original_glcm_InverseVariance', 'lPUT_original_glszm_LargeAreaLowGrayLevelEmphasis', 'rSN_original_gldm_DependenceEntropy', 'rTHA_original_gldm_DependenceEntropy', 'rPUT_original_glszm_SizeZoneNonUniformityNormalized', 'rGPi_original_firstorder_Minimum', 'lSN_original_firstorder_Skewness', 'rPUT_original_gldm_SmallDependenceHighGrayLevelEmphasis', 'lTHA_original_glcm_Imc2', 'lSTN_original_glcm_SumSquares', 'rSN_original_glrlm_ShortRunLowGrayLevelEmphasis', 'rPUT_original_glcm_Idn', 'rRN_original_glszm_LargeAreaLowGrayLevelEmphasis', 'lGPi_original_glcm_ClusterShade', 'lPUT_original_glcm_Idmn']
#
# LASSO Selected alpha: 44.10882397653814
#
# LASSO Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis'
#  'rSTN_original_glcm_ClusterProminence']
#
# RFE Selected features: ['rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis'
#  'rTHA_original_glszm_LargeAreaHighGrayLevelEmphasis']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7153167602245388
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9450013365410318
#
# AUC test 0.7632575757575758
#
# Accuracy train 0.8670520231213873
#
# Accuracy test 0.717391304347826
#
# Model: mlp
#
# AUC train 0.6778936113338679
#
# AUC test 0.6893939393939394
#
# Accuracy train 0.6127167630057804
#
# Accuracy test 0.6956521739130435
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7205960973001871
#
# AUC test 0.7878787878787878
#
# Accuracy train 0.6416184971098265
#
# Accuracy test 0.717391304347826
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.7178030303030304
#
# Accuracy train 1.0
#
# Accuracy test 0.6304347826086957
#
# Model: mlp
#
# AUC train 0.702619620422347
#
# AUC test 0.7727272727272727
#
# Accuracy train 0.6358381502890174
#
# Accuracy test 0.6304347826086957

# %%
# paired t test
from scipy.stats import ttest_rel
print(ttest_rel(baseline_auc['svc'], img_auc['svc'], alternative='less'))
print(ttest_rel(baseline_auc['xgboost'], img_auc['xgboost'], alternative='less'))
print(ttest_rel(baseline_auc['mlp'], img_auc['mlp'], alternative='less'))
# Out:
# TtestResult(statistic=-15.509972888570804, pvalue=4.217625955954912e-08, df=9)
