# %%
from src.model.pipeline import run
import os

# %%
# Root directory as working directory
os.chdir('..')
os.getcwd()
# Out:
# '/home/biobot/disk/ldopa'

# %% [markdown]
# Baseline:
#
# SVM: 0.765 0.710
#
# XgBoost: 0.966 0.746
#
# AUC Table:
# | Model | Baseline | Texture |
# | --- | --- | --- |
# | SVM | 0.710 |  |
# | XgBoost | 0.746 |  |

# %%
run('pat_data', ['classification/2'], [['t1_radiomic']], print, plot_flag=True, feature_selection=True)
# Out:
# Task: classification/2
#
# Feature: ['t1_radiomic_full']
#
# SEX chi2 p: 0.5414803876006902
# CAT chi2 p: 0.9510706628888684
# AGE Normaltest p_train: [0.07505303], p_test: [0.48389882]
# AGE t-test p: Ttest_indResult(statistic=array([1.54953415]), pvalue=array([0.12271054]))
# NUPDR3OF Normaltest p_train: [0.01407325], p_test: [0.53859285]
# NUPDR3OF ranksums p: RanksumsResult(statistic=array([0.53408144]), pvalue=array([0.59328519]))
# LEDD Normaltest p_train: [2.56158925e-12], p_test: [0.1798008]
# LEDD ranksums p: RanksumsResult(statistic=array([0.51837316]), pvalue=array([0.60419794]))
# DURATION Normaltest p_train: [0.00553476], p_test: [0.13860719]
# DURATION ranksums p: RanksumsResult(statistic=array([-0.45554005]), pvalue=array([0.64872076]))
# 100%|██████████| 50/50 [00:01<00:00, 26.29it/s]
# mRMR Selected features: ['rSN_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rPUT_original_firstorder_Kurtosis', 'lSTN_original_glcm_ClusterShade', 'rTHA_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_glcm_Idmn', 'rSN_original_firstorder_Skewness', 'rPUT_original_glcm_Correlation', 'rTHA_original_glcm_Idn', 'rSTN_original_glcm_ClusterShade', 'lSTN_original_firstorder_Maximum', 'rSN_original_firstorder_Kurtosis', 'rGPi_original_glcm_ClusterShade', 'rSTN_original_glcm_Correlation', 'lGPe_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rRN_original_glszm_SmallAreaLowGrayLevelEmphasis', 'rCAU_original_glszm_LargeAreaHighGrayLevelEmphasis', 'lGPi_original_firstorder_Minimum', 'lSTN_original_firstorder_Kurtosis', 'rGPe_original_firstorder_Minimum', 'rGPi_original_firstorder_Skewness', 'rSTN_original_firstorder_Kurtosis', 'rRN_original_firstorder_Maximum', 'lGPi_original_glcm_JointAverage', 'rTHA_original_glcm_Imc1', 'lSTN_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rGPi_original_firstorder_Minimum', 'lGPe_original_firstorder_Kurtosis', 'lSN_original_firstorder_Skewness', 'rSN_original_glszm_SmallAreaHighGrayLevelEmphasis', 'lGPe_original_firstorder_90Percentile', 'lGPe_original_firstorder_10Percentile', 'rGPi_original_firstorder_Maximum', 'rTHA_original_gldm_SmallDependenceLowGrayLevelEmphasis', 'rCAU_original_firstorder_Kurtosis', 'rRN_original_glcm_Correlation', 'lGPe_original_glcm_Correlation', 'rGPi_original_glszm_SmallAreaLowGrayLevelEmphasis', 'lGPe_original_gldm_LargeDependenceHighGrayLevelEmphasis', 'rSTN_original_firstorder_Maximum', 'lTHA_original_glcm_Idn', 'lGPi_original_glcm_Correlation', 'lTHA_original_glszm_LargeAreaHighGrayLevelEmphasis', 'rSN_original_firstorder_Maximum', 'rRN_original_gldm_DependenceEntropy', 'lPUT_original_glszm_SmallAreaLowGrayLevelEmphasis', 'rGPe_original_glcm_ClusterShade', 'rPUT_original_firstorder_TotalEnergy', 'lRN_original_glcm_Idmn', 'rRN_original_firstorder_Skewness', 'rPUT_original_firstorder_90Percentile']
#
# LASSO Selected alpha: 0.018373481079167347
# LASSO Selected features: ['rGPe_original_firstorder_Minimum']
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7427158513766372
#
# ConfidenceInterval(low=0.6644055276285333, high=0.811461797024789)
#
# AUC test 0.7746212121212122
#
# ConfidenceInterval(low=0.6238886742247436, high=0.8939393939393939)
# Model: xgboost
#
# AUC train 0.9862336273723604
#
# ConfidenceInterval(low=0.9663808932527355, high=0.9948754664332362)
#
# AUC test 0.7140151515151516
#
# ConfidenceInterval(low=0.5595529236184056, high=0.8438095238095238)
