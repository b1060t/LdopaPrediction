# %%
from src.model.pipeline import run
import os

# %%
# Root directory as working directory
os.chdir('..')
os.getcwd()
# Out:
# '/home/biobot/disk/ldopa'

# %% [markdown]
# Baseline:
#
# SVM: 0.765 0.710
#
# XgBoost: 0.966 0.746
#
# AUC Table:
# | Model | Baseline | Texture |
# | --- | --- | --- |
# | SVM | 0.710 |  |
# | XgBoost | 0.746 |  |

# %%
run('pat_data', ['classification/2'], [['threshold_sgm']], print, plot_flag=True, feature_selection=True)
# Out:
# Task: classification/2
#
# Feature: ['threshold_sgm']
#
# SEX chi2 p: 0.5414803876006902
# CAT chi2 p: 0.9510706628888684
# AGE Normaltest p_train: [0.07505303], p_test: [0.48389882]
# AGE t-test p: Ttest_indResult(statistic=array([1.54953415]), pvalue=array([0.12271054]))
# NUPDR3OF Normaltest p_train: [0.01407325], p_test: [0.53859285]
# NUPDR3OF ranksums p: RanksumsResult(statistic=array([0.53408144]), pvalue=array([0.59328519]))
# LEDD Normaltest p_train: [2.56158925e-12], p_test: [0.1798008]
# LEDD ranksums p: RanksumsResult(statistic=array([0.51837316]), pvalue=array([0.60419794]))
# DURATION Normaltest p_train: [0.00553476], p_test: [0.13860719]
# DURATION ranksums p: RanksumsResult(statistic=array([-0.45554005]), pvalue=array([0.64872076]))
# 100%|██████████| 50/50 [00:01<00:00, 41.31it/s]
# mRMR Selected features: ['VOX_11', 'VOX_58', 'VOX_14', 'VOX_42', 'VOX_2', 'VOX_44', 'VOX_59', 'VOX_67', 'VOX_60', 'VOX_33', 'VOX_43', 'VOX_50', 'VOX_36', 'VOX_5', 'VOX_22', 'VOX_57', 'VOX_3', 'VOX_38', 'VOX_28', 'VOX_30', 'VOX_46', 'VOX_63', 'VOX_1', 'VOX_7', 'VOX_8', 'VOX_26', 'VOX_55', 'VOX_34', 'VOX_47', 'VOX_23', 'VOX_15', 'VOX_54', 'VOX_19', 'VOX_66', 'VOX_25', 'VOX_48', 'VOX_17', 'VOX_32', 'VOX_18', 'VOX_13', 'VOX_16', 'VOX_70', 'VOX_37', 'VOX_69', 'VOX_12', 'VOX_29', 'VOX_35', 'VOX_64', 'VOX_24', 'VOX_62']
#
# LASSO Selected alpha: 0.017088293915203192
# LASSO Selected features: ['VOX_11' 'VOX_14']
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7641005078855921
#
# ConfidenceInterval(low=0.6912163833778321, high=0.8323292705204286)
#
# AUC test 0.6742424242424243
#
# ConfidenceInterval(low=0.48878179654159154, high=0.8231422077520661)
# Model: xgboost
#
# AUC train 0.9240844693932103
#
# ConfidenceInterval(low=0.8736131967789013, high=0.9565809680997245)
#
# AUC test 0.6818181818181818
#
# ConfidenceInterval(low=0.506696297321332, high=0.8203728931731832)
