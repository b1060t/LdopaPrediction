# %%
from src.model.pipeline import run
import os

# %%
# Root directory as working directory
os.chdir('..')
os.getcwd()
# Out:
# '/home/biobot/disk/ldopa'

# %% [markdown]
# Baseline:
#
# SVM: 0.765 0.710
#
# XgBoost: 0.966 0.746

# %%
run('pat_data', ['classification/2'], [['wm_pca']], print, plot_flag=True)
# Out:
# Task: classification/2
#
# Feature: ['wm_pca']
#
# SEX chi2 p: 0.5414803876006902
# CAT chi2 p: 0.9510706628888684
# AGE Normaltest p_train: [0.07505303], p_test: [0.48389882]
# AGE t-test p: Ttest_indResult(statistic=array([1.54953415]), pvalue=array([0.12271054]))
# NUPDR3OF Normaltest p_train: [0.01407325], p_test: [0.53859285]
# NUPDR3OF ranksums p: RanksumsResult(statistic=array([0.53408144]), pvalue=array([0.59328519]))
# LEDD Normaltest p_train: [2.56158925e-12], p_test: [0.1798008]
# LEDD ranksums p: RanksumsResult(statistic=array([0.51837316]), pvalue=array([0.60419794]))
# DURATION Normaltest p_train: [0.00553476], p_test: [0.13860719]
# DURATION ranksums p: RanksumsResult(statistic=array([-0.45554005]), pvalue=array([0.64872076]))
# 100%|██████████| 50/50 [00:01<00:00, 41.17it/s]
# mRMR Selected features: ['PCA_27', 'PCA_15', 'PCA_34', 'PCA_65', 'PCA_31', 'PCA_62', 'PCA_35', 'PCA_18', 'PCA_69', 'PCA_5', 'PCA_47', 'PCA_3', 'PCA_10', 'PCA_37', 'PCA_36', 'PCA_4', 'PCA_57', 'PCA_30', 'PCA_9', 'PCA_64', 'PCA_70', 'PCA_42', 'PCA_19', 'PCA_61', 'PCA_13', 'PCA_39', 'PCA_23', 'PCA_52', 'PCA_28', 'PCA_12', 'PCA_43', 'PCA_46', 'PCA_50', 'PCA_63', 'PCA_25', 'PCA_2', 'PCA_17', 'PCA_20', 'PCA_22', 'PCA_58', 'PCA_16', 'PCA_6', 'PCA_41', 'PCA_40', 'PCA_44', 'PCA_60', 'PCA_14', 'PCA_21', 'PCA_49', 'PCA_7']
#
# LASSO Selected alpha: 0.01213205916868297
# LASSO Selected features: ['PCA_27']
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7226009088479016
#
# ConfidenceInterval(low=0.6470584120203171, high=0.7992766610782611)
#
# AUC test 0.6875
#
# ConfidenceInterval(low=0.503343594197961, high=0.829185206255474)
# Model: xgboost
#
# AUC train 0.8436246992782679
#
# ConfidenceInterval(low=0.7754412371260958, high=0.8963644760133229)
#
# AUC test 0.7357954545454546
#
# ConfidenceInterval(low=0.5667443337570899, high=0.8653596376402494)
