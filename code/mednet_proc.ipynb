# %%
from src.model.pipeline import run
import os

# %%
# Root directory as working directory
os.chdir('..')
os.getcwd()
# Out:
# '/home/biobot/disk/ldopa'

# %% [markdown]
# Baseline:
#
# SVM: 0.765 0.710
#
# XgBoost: 0.966 0.746
#
# AUC Table:
# | Model | Baseline | Texture |
# | --- | --- | --- |
# | SVM | 0.710 |  |
# | XgBoost | 0.746 |  |

# %%
b1, i1 = run('pat_data', ['classification/2'], [[
    'mednet_features'
    ]], print, plot_flag=False, feature_selection=True, cal_baselines=True)
# Out:
# Task: classification/2
#
# Feature: ['mednet_features']
#
# SEX chi2 p: 0.5414803876006902
# CAT chi2 p: 0.9510706628888684
# AGE Normaltest p_train: [0.07505303], p_test: [0.48389882]
# AGE t-test p: Ttest_indResult(statistic=array([1.54953415]), pvalue=array([0.12271054]))
# NUPDR3OF Normaltest p_train: [0.01407325], p_test: [0.53859285]
# NUPDR3OF ranksums p: RanksumsResult(statistic=array([0.53408144]), pvalue=array([0.59328519]))
# LEDD Normaltest p_train: [2.56158925e-12], p_test: [0.1798008]
# LEDD ranksums p: RanksumsResult(statistic=array([0.51837316]), pvalue=array([0.60419794]))
# DURATION Normaltest p_train: [0.00553476], p_test: [0.13860719]
# DURATION ranksums p: RanksumsResult(statistic=array([-0.45554005]), pvalue=array([0.64872076]))
# 100%|██████████| 50/50 [00:31<00:00,  1.58it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7654370489174017
#
# AUC test 0.7102272727272727
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9662523389468057
#
# AUC test 0.7462121212121212
#
# Accuracy train 0.9017341040462428
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7110398289227479
#
# AUC test 0.7784090909090909
#
# Accuracy train 0.5028901734104047
#
# Accuracy test 0.5217391304347826
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7916332531408715
#
# AUC test 0.8333333333333334
#
# Accuracy train 0.7398843930635838
#
# Accuracy test 0.782608695652174
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.8276515151515151
#
# Accuracy train 1.0
#
# Accuracy test 0.6956521739130435
#
# Model: mlp
#
# AUC train 0.744186046511628
#
# AUC test 0.7821969696969697
#
# Accuracy train 0.6763005780346821
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:32<00:00,  1.56it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7380379577653033
#
# AUC test 0.7291666666666666
#
# Accuracy train 0.7052023121387283
#
# Accuracy test 0.6521739130434783
#
# Model: xgboost
#
# AUC train 0.9472734562951083
#
# AUC test 0.7556818181818181
#
# Accuracy train 0.8728323699421965
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7158513766372627
#
# AUC test 0.7784090909090909
#
# Accuracy train 0.6473988439306358
#
# Accuracy test 0.717391304347826
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.8510425020048115
#
# AUC test 0.8238636363636364
#
# Accuracy train 0.7745664739884393
#
# Accuracy test 0.6956521739130435
#
# Model: xgboost
#
# AUC train 0.8769713980219193
#
# AUC test 0.8693181818181819
#
# Accuracy train 0.7976878612716763
#
# Accuracy test 0.8043478260869565
#
# Model: mlp
#
# AUC train 0.7574178027265437
#
# AUC test 0.7916666666666666
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.717391304347826
# 100%|██████████| 50/50 [00:32<00:00,  1.55it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7159850307404437
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9902432504677894
#
# AUC test 0.7518939393939394
#
# Accuracy train 0.9364161849710982
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7125100240577387
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6242774566473989
#
# Accuracy test 0.6086956521739131
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.8449612403100775
#
# AUC test 0.8295454545454546
#
# Accuracy train 0.7687861271676301
#
# Accuracy test 0.6956521739130435
#
# Model: xgboost
#
# AUC train 0.9791499599037691
#
# AUC test 0.7310606060606061
#
# Accuracy train 0.9190751445086706
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7759957230686982
#
# AUC test 0.8314393939393939
#
# Accuracy train 0.6994219653179191
#
# Accuracy test 0.7608695652173914
# 100%|██████████| 50/50 [00:32<00:00,  1.55it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7659716653301256
#
# AUC test 0.7121212121212122
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9951884522854852
#
# AUC test 0.7367424242424243
#
# Accuracy train 0.953757225433526
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.644613739641807
#
# AUC test 0.7291666666666666
#
# Accuracy train 0.5895953757225434
#
# Accuracy test 0.6521739130434783
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.8508420208500401
#
# AUC test 0.8238636363636364
#
# Accuracy train 0.7745664739884393
#
# Accuracy test 0.6956521739130435
#
# Model: xgboost
#
# AUC train 0.8678160919540231
#
# AUC test 0.8304924242424243
#
# Accuracy train 0.7861271676300579
#
# Accuracy test 0.782608695652174
#
# Model: mlp
#
# AUC train 0.7721197540764502
#
# AUC test 0.8162878787878788
#
# Accuracy train 0.7225433526011561
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:32<00:00,  1.54it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7157177225340817
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.7771986099973269
#
# AUC test 0.725378787878788
#
# Accuracy train 0.6763005780346821
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7016840417000803
#
# AUC test 0.706439393939394
#
# Accuracy train 0.6358381502890174
#
# Accuracy test 0.6739130434782609
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7916332531408715
#
# AUC test 0.8333333333333334
#
# Accuracy train 0.7398843930635838
#
# Accuracy test 0.782608695652174
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.8049242424242424
#
# Accuracy train 1.0
#
# Accuracy test 0.717391304347826
#
# Model: mlp
#
# AUC train 0.7825447741245656
#
# AUC test 0.759469696969697
#
# Accuracy train 0.7167630057803468
#
# Accuracy test 0.6521739130434783
# 100%|██████████| 50/50 [00:32<00:00,  1.54it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7658380112269447
#
# AUC test 0.7121212121212122
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.950414327719861
#
# AUC test 0.7651515151515152
#
# Accuracy train 0.884393063583815
#
# Accuracy test 0.7391304347826086
#
# Model: mlp
#
# AUC train 0.6963378775728416
#
# AUC test 0.7575757575757577
#
# Accuracy train 0.653179190751445
#
# Accuracy test 0.6956521739130435
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.8005880780539962
#
# AUC test 0.8390151515151515
#
# Accuracy train 0.7283236994219653
#
# Accuracy test 0.7391304347826086
#
# Model: xgboost
#
# AUC train 0.8772387062282812
#
# AUC test 0.8276515151515151
#
# Accuracy train 0.791907514450867
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7707832130446405
#
# AUC test 0.8181818181818181
#
# Accuracy train 0.7109826589595376
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:32<00:00,  1.54it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7383052659716653
#
# AUC test 0.7272727272727273
#
# Accuracy train 0.7052023121387283
#
# Accuracy test 0.6521739130434783
#
# Model: xgboost
#
# AUC train 0.9251537022186581
#
# AUC test 0.7272727272727273
#
# Accuracy train 0.8554913294797688
#
# Accuracy test 0.6956521739130435
#
# Model: mlp
#
# AUC train 0.6849772788024592
#
# AUC test 0.6079545454545454
#
# Accuracy train 0.5722543352601156
#
# Accuracy test 0.4782608695652174
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.9112536754878375
#
# AUC test 0.8106060606060607
#
# Accuracy train 0.838150289017341
#
# Accuracy test 0.6521739130434783
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.7708333333333334
#
# Accuracy train 1.0
#
# Accuracy test 0.6521739130434783
#
# Model: mlp
#
# AUC train 0.789494787489976
#
# AUC test 0.821969696969697
#
# Accuracy train 0.7398843930635838
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:32<00:00,  1.54it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7159850307404437
#
# AUC test 0.7357954545454546
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9037690457097033
#
# AUC test 0.7234848484848485
#
# Accuracy train 0.815028901734104
#
# Accuracy test 0.6304347826086957
#
# Model: mlp
#
# AUC train 0.6627906976744187
#
# AUC test 0.5833333333333334
#
# Accuracy train 0.630057803468208
#
# Accuracy test 0.5652173913043478
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.791566426089281
#
# AUC test 0.8333333333333334
#
# Accuracy train 0.7398843930635838
#
# Accuracy test 0.782608695652174
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.7784090909090909
#
# Accuracy train 0.9942196531791907
#
# Accuracy test 0.6739130434782609
#
# Model: mlp
#
# AUC train 0.7657043571237637
#
# AUC test 0.7443181818181819
#
# Accuracy train 0.7283236994219653
#
# Accuracy test 0.6304347826086957
# 100%|██████████| 50/50 [00:32<00:00,  1.54it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7151831061213579
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9161320502539428
#
# AUC test 0.7386363636363635
#
# Accuracy train 0.8323699421965318
#
# Accuracy test 0.7391304347826086
#
# Model: mlp
#
# AUC train 0.6875167067628977
#
# AUC test 0.7026515151515151
#
# Accuracy train 0.653179190751445
#
# Accuracy test 0.6521739130434783
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.8450948944132585
#
# AUC test 0.8295454545454546
#
# Accuracy train 0.7687861271676301
#
# Accuracy test 0.6956521739130435
#
# Model: xgboost
#
# AUC train 1.0
#
# AUC test 0.7916666666666667
#
# Accuracy train 1.0
#
# Accuracy test 0.7608695652173914
#
# Model: mlp
#
# AUC train 0.7923015236567763
#
# AUC test 0.8143939393939393
#
# Accuracy train 0.7341040462427746
#
# Accuracy test 0.6956521739130435
# 100%|██████████| 50/50 [00:32<00:00,  1.55it/s]
# mRMR Selected features: ['resnet_7020', 'resnet_11418', 'resnet_12898', 'resnet_3361', 'resnet_7763', 'resnet_5430', 'resnet_2011', 'resnet_3294', 'resnet_7509', 'resnet_7044', 'resnet_25', 'resnet_3805', 'resnet_7314', 'resnet_6855', 'resnet_8038', 'resnet_9756', 'resnet_8513', 'resnet_2015', 'resnet_3459', 'resnet_7972', 'resnet_11394', 'resnet_13059', 'resnet_13074', 'resnet_8869', 'resnet_6567', 'resnet_11313', 'resnet_874', 'resnet_152', 'resnet_8241', 'resnet_8562', 'resnet_5097', 'resnet_2724', 'resnet_9261', 'resnet_4063', 'resnet_7239', 'resnet_4696', 'resnet_12295', 'resnet_11067', 'resnet_7', 'resnet_13122', 'resnet_12555', 'resnet_9188', 'resnet_4431', 'resnet_12889', 'resnet_3479', 'resnet_8599', 'resnet_810', 'resnet_5549', 'resnet_1915', 'resnet_10653']
#
# LASSO Selected alpha: 0.007844009632799416
#
# LASSO Selected features: ['resnet_7020' 'resnet_11418' 'resnet_7763' 'resnet_3294' 'resnet_7509'
#  'resnet_7044' 'resnet_8038' 'resnet_13074' 'resnet_874' 'resnet_9261'
#  'resnet_12889' 'resnet_810']
#
# RFE Selected features: ['resnet_7020' 'resnet_7763' 'resnet_3294' 'resnet_7509' 'resnet_7044'
#  'resnet_13074' 'resnet_874' 'resnet_12889' 'resnet_810']
#
# Demo + Clinic:
#
# Model: svc
#
# AUC train 0.7153167602245388
#
# AUC test 0.7367424242424242
#
# Accuracy train 0.6705202312138728
#
# Accuracy test 0.6739130434782609
#
# Model: xgboost
#
# AUC train 0.9450013365410318
#
# AUC test 0.7632575757575758
#
# Accuracy train 0.8670520231213873
#
# Accuracy test 0.717391304347826
#
# Model: mlp
#
# AUC train 0.6815022721197541
#
# AUC test 0.6553030303030303
#
# Accuracy train 0.6473988439306358
#
# Accuracy test 0.6739130434782609
#
# Demo + Clinic + Img:
#
# Model: svc
#
# AUC train 0.7916332531408715
#
# AUC test 0.8333333333333334
#
# Accuracy train 0.7398843930635838
#
# Accuracy test 0.782608695652174
#
# Model: xgboost
#
# AUC train 0.9981288425554665
#
# AUC test 0.7916666666666666
#
# Accuracy train 0.976878612716763
#
# Accuracy test 0.717391304347826
#
# Model: mlp
#
# AUC train 0.7833466987436514
#
# AUC test 0.8162878787878788
#
# Accuracy train 0.7341040462427746
#
# Accuracy test 0.7608695652173914

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
b = [np.max([b1['svc'][i], b1['xgboost'][i], b1['mlp'][i]]) for i in range(len(b1['svc']))]
plt.plot(b, linestyle='solid')
#plt.plot(i1['xgboost'], linestyle='dashed', alpha=0.5)
#plt.plot(i2['xgboost'], linestyle='dashed', alpha=0.5)
#plt.plot(i3['xgboost'], linestyle='dashed', alpha=0.5)
#plt.plot(i4['xgboost'], linestyle='dashed', alpha=0.5)
import numpy as np
#plt.plot(np.mean([i1['xgboost'], i2['xgboost'], i3['xgboost'], i4['xgboost']], axis=0), linestyle='solid')
plt.plot(i1['xgboost'], linestyle='solid')
plt.legend(labels=['Baseline', 'Image'])
#plt.legend(labels=['Baseline', 'Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4', 'Average'])
plt.title('XgBoost')
plt.ylabel('AUC')
plt.xlabel('Random Seed')
plt.show()

import seaborn as sns
import matplotlib.pyplot as plt
b = [np.max([b1['svc'][i], b1['xgboost'][i], b1['mlp'][i]]) for i in range(len(b1['svc']))]
plt.plot(b, linestyle='solid')
#plt.plot(i1['mlp'], linestyle='dashed', alpha=0.5)
#plt.plot(i2['mlp'], linestyle='dashed', alpha=0.5)
#plt.plot(i3['mlp'], linestyle='dashed', alpha=0.5)
#plt.plot(i4['mlp'], linestyle='dashed', alpha=0.5)
import numpy as np
plt.plot(i1['mlp'], linestyle='solid')
plt.legend(labels=['Baseline', 'Image'])
#plt.plot(np.mean([i1['mlp'], i2['mlp'], i3['mlp'], i4['mlp']], axis=0), linestyle='solid')
#plt.legend(labels=['Baseline', 'Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4', 'Average'])
plt.title('MLP')
plt.ylabel('AUC')
plt.xlabel('Random Seed')
plt.show()

b = [np.max([b1['svc'][i], b1['xgboost'][i], b1['mlp'][i]]) for i in range(len(b1['svc']))]
plt.plot(b, linestyle='solid')
#plt.plot(i1['svc'], linestyle='dashed', alpha=0.5)
#plt.plot(i2['svc'], linestyle='dashed', alpha=0.5)
#plt.plot(i3['svc'], linestyle='dashed', alpha=0.5)
#plt.plot(i4['svc'], linestyle='dashed', alpha=0.5)
import numpy as np
plt.plot(i1['svc'], linestyle='solid')
plt.legend(labels=['Baseline', 'Image'])
#plt.plot(np.mean([i1['svc'], i2['svc'], i3['svc'], i4['svc']], axis=0), linestyle='solid')
#plt.legend(labels=['Best among all', 'Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4', 'Average'])
plt.title('SVC')
plt.ylabel('AUC')
plt.xlabel('Random Seed')
plt.show()

# %%
print('Best Baseline mean: {}, std: {}'.format(np.mean(b), np.std(b)))
print('SVM mean: {}, std: {}'.format(np.mean(i1['svc']), np.std(i1['svc'])))
print('XgBoost mean: {}, std: {}'.format(np.mean(i1['xgboost']), np.std(i1['xgboost'])))
print('MLP mean: {}, std: {}'.format(np.mean(i1['mlp']), np.std(i1['mlp'])))
# Out:
# Best Baseline mean: 0.7512310606060606, std: 0.017907745312342307
# SVM mean: 0.8289772727272728, std: 0.007530642178814783
# XgBoost mean: 0.8023674242424242, std: 0.03666142763254065
# MLP mean: 0.7996212121212121, std: 0.027690404367419773
